# %% [markdown]
# # U.S. Medical Insurance

# %%
# import modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load dataset
df = pd.read_csv('insurance.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# display the charts correctly
# %matplotlib inline
plt.rcParams['figure.figsize'] = (5, 3)
plt.rcParams['figure.dpi'] = 100

# %%
# create the initial variables below
age = df['age']
sex = df['sex']
bmi = df['bmi']
children = df['children']
smoker = df['smoker']
region = df['region']
charges = df['charges']
charges
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
class PatientInfo:
    def __init__(self, age, sex, bmi, children, smoker, region, charges):
        self.age = age
        self.sex = sex
        self.bmi = bmi
        self.children = children
        self.smoker = smoker
        self.region = region
        self.charges = charges

    def analyze_age(self):
        age_mn = self.age.mean()
        age_mn_rd = np.round(age_mn, 1)
        print("Average patient age:", age_mn_rd)

    def analyze_sex(self):
        males = self.sex.value_counts()[0]
        females = self.sex.value_counts()[1]        
        print("Count for male:", males)
        print("Count for female:", females)

    def unique_regions(self):
        print(self.region.value_counts())
    
    def avg_charges(self):
        charge_mn = self.charges.mean()
        charge_mn_rd = np.round(charge_mn, 2)
        print("Average yearly medical insurance charges:", charge_mn_rd)

# %%
patient_info = PatientInfo(age, sex, bmi, children, smoker, region, charges)

# %%
patient_info.analyze_age()
# Out:
# Average patient age: 39.2

# %%
patient_info.analyze_sex()
# Out:
# Count for male: 676
# Count for female: 662

# %%
patient_info.unique_regions()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
patient_info.avg_charges()
# Out:
# Average yearly medical insurance charges: 13270.42

# %%
plt.plot()
plt.legend(bbox_to_anchor = (1, .75))

# %%
plt.bar(df.children)
#bottom=
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plt.bar(df.children)
#       2 #bottom=
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
plt.title('')
plt.xlabel('')
plt.ylabel('')

# %%
plt.xlim()

# %%
plt.errorbar()

# %%
plt.scatter()

# %%
plt.pie(df.region)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plt.pie(df.region)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py:2799, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    2792 @_copy_docstring_and_deprecators(Axes.pie)
#    2793 def pie(
#    2794         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2797         textprops=None, center=(0, 0), frame=False,
#    2798         rotatelabels=False, *, normalize=True, hatch=None, data=None):
# -> 2799     return gca().pie(
#    2800         x, explode=explode, labels=labels, colors=colors,
#    2801         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
# ...

# %%
plt.hist(df.age)
plt.title('Distribution of patient age')
plt.xlabel('Age')
plt.ylabel('Number of patients')
# Out:
# Text(0, 0.5, 'Number of patients')

# %%
plt.savefig('ageHist.png', dpi=150, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(10,4), tight_layout=True, facecolor='lightgray')

# %%
fig.suptitle('', fontsize=24, x=.45, y=.95)
fig.supxlabel('Time')
fig.ubplots_adjust(hspace=.5, wspace=.25)

# %%
plt.subplot()

# %%
plt.axline()

# %%
plt.annotate('', xy=(15,35), ha='left', #backgroundcolor='lightgray')
             xytext=(17,40), fontsize=14, color='blue',
             arrowprops=dict(arrowstyle='-|>', color='blue'))
